# %% [markdown]
# # General-domain LM pretraining

# %%
import json
import pathlib

from fastai.text import *

import numpy as np
import pandas as pd
import html

from sklearn.model_selection import train_test_split

# %%
from pathlib import Path

from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
root_dir = "/content/gdrive/My Drive/"
#base_dir = root_dir + 'fastai-v3/'

path = Path('/content/gdrive/My Drive/Colab Notebooks/nlp/pt_lm/')
# Out:
# Mounted at /content/gdrive

# %%
BOS = 'xbos'  # beginning-of-sentence tag
FLD = 'xfld'  # data field tag

#PATH = pathlib.Path("lm/pt/data/")
PATH = pathlib.Path("/mnt/aa/nlp/data/")

# %%
#LM_PATH=Path('lm/pt/pt_lm/')
LM_PATH=Path('/mnt/aa/nlp/pt_lm/')
LM_PATH.mkdir(exist_ok=True)

# %% [markdown]
# ## Tokenization

# %%
LANG_FILENAMES = [str(f) for f in PATH.rglob("*/*")]
print(len(LANG_FILENAMES))
LANG_FILENAMES[0:5]
# Out:
# 1642
# ['/mnt/aa/nlp/data/AA/wiki_00',
#  '/mnt/aa/nlp/data/AA/wiki_01',
#  '/mnt/aa/nlp/data/AA/wiki_02',
#  '/mnt/aa/nlp/data/AA/wiki_03',
#  '/mnt/aa/nlp/data/AA/wiki_04']

# %%
LANG_TEXT = []
for i in LANG_FILENAMES:
    for line in open(i):
        LANG_TEXT.append(json.loads(line))
        
LANG_TEXT = pd.DataFrame(LANG_TEXT)

# %%
LANG_TEXT.head()
# Out:
#     id                                               text  \
# 0  220  Astronomia\n\nAstronomia é uma ciência natural...
# 1  223  América Latina\n\nA América Latina (; ) é uma ...
# 2  224  Albino Forjaz de Sampaio\n\nAlbino Maria Perei...
# 3  226  Anno Domini\n\nAnno Domini (expressão em latim...
# 4  228  Aquiles\n\nAquiles (), na mitologia grega, foi...
#
#                       title                                      url
# 0                Astronomia  https://pt.wikipedia.org/wiki?curid=220
# 1            América Latina  https://pt.wikipedia.org/wiki?curid=223
# 2  Albino Forjaz de Sampaio  https://pt.wikipedia.org/wiki?curid=224
# 3               Anno Domini  https://pt.wikipedia.org/wiki?curid=226
# 4                   Aquiles  https://pt.wikipedia.org/wiki?curid=228

# %%
###  sort LANG_TEXT by length of text
s = LANG_TEXT.text.str.len().sort_values(ascending=False).index
LANG_TEXT = LANG_TEXT.reindex(s)
LANG_TEXT = LANG_TEXT.reset_index(drop=True)

# %%
LANG_TEXT
# Out:
#             id                                               text  \
# 0      1018503  Lista de vilões de Ben 10\n\nNa lista a seguir...
# 1      2737450  História da televisão no Brasil\n\nA história ...
# 2        31862  Magnetismo\n\nEm física e demais ciências natu...
# 3       198795  Wally West\n\nWally West é um personagem de hi...
# 4       182603  Guerra Irã-Iraque\n\nA foi um conflito militar...
# 5        27121  Quito\n\nQuito (; ), originalmente "San Franci...
# 6          232  Aquecimento global\n\nAquecimento global é o p...
# 7      3143570  Cronologia da Rede Globo\n\nEm julho de 1957, ...
# 8      4286052  Idade Antiga\n\nIdade Antiga ou Antiguidade, n...
# 9      2324636  Cronologia da RecordTV\n\nNos anos 70, a TV Re...
# 10     1475770  Estereoquímica\n\nA estereoquímica é uma área ...
# 11     3164793  História do Sistema Brasileiro de Televisão\n\...
# 12     5346732  História operacional da Luftwaffe na Segunda G...
# 13     5084779  Governo Michel Temer\n\nO governo Michel Temer...
# 14     4427907  Anarquismo no Brasil\n\nO anarquismo no Brasil...
# 15     2946203  Lista de personagens de Inazuma Eleven\n\nSect...
# 16        9105  Cabala\n\nKabbalah—, literalmente "(receber/tr...
# 17       97372  Imigração portuguesa no Brasil\n\nImigração po...
# 18       97388  Imigração italiana no Brasil\n\nA imigração it...
# 19      127871  História em quadrinhos no Brasil\n\nAs históri...
# 20         989  História do Japão\n\nA é a sequência de evento...
# 21      132239  Gueorgui Júkov\n\nGueorgui Konstantínovitch Jú...
# 22     1321355  História das relações internacionais do Brasil...
# 23        5096  Guerra das Malvinas\n\nA Guerra das Malvinas (...
# 24      103169  Acadêmicos do Salgueiro\n\nGrêmio Recreativo E...
# 25       34153  Piratini\n\nPiratini é um município brasileiro...
# 26         230  Anarquismo\n\nAnarquismo é uma ideologia polít...
# 27     1562777  Lista de alienígenas de Ben 10\n\nEsta é a lis...
# 28     4528100  Anthony Bottoms\n\nAnthony Edward Bottoms (Chi...
# 29     2564674  John Keith Irwin\n\nJohn Keith Irwin (Los Ange...
# ...        ...                                                ...
# 47823    36747  Asmara\n\nAsmara (em tigrínio "Asmera") é a ca...
# 47824  2184761  Bate Folha (Rio de Janeiro)\n\nBate - Folha, R...
# 47825   267762  Parque Nacional da Chapada dos Veadeiros\n\nO ...
# 47826  4120876  Feminicídio\n\nFemicídio ou feminicídio é um t...
# 47827   157805  Fernanda Venturini\n\nFernanda Porto Venturini...
# 47828  4247608  Voo SA de Transport Aérien 730\n\nO Voo SA de ...
# 47829  5660911  AU Microscopii\n\nAU Microscopii (AU Mic) é um...
# 47830  4965390  Nossa Senhora Achiropita\n\nNossa Senhora Achi...
# 47831  5158557  Ludgero Pinto Basto\n\nLudgero Eugénio Pinto B...
# 47832  2037181  Instituto de Economia Agrícola\n\nO Instituto ...
# 47833    74380  Francesco Matarazzo\n\nFrancesco Antonio Maria...
# 47834   406696  Pepe Reina\n\nJosé Manuel Reina Páez, mais con...
# 47835  4763784  Companhia de Teatro Zaira Médice\n\nCompanhia ...
# 47836  1114270  Café (estabelecimento)\n\nUm café, cafeteria o...
# 47837  5483057  Caso do Rio de Janeiro\n\nO caso do Rio de Jan...
# 47838  5132804  Blockstream\n\nBlockstream é uma companhia de ...
# 47839  1103465  Codex Aleppo\n\nCódice ou Códex de Aleppo (), ...
# 47840   268851  Close Encounters of the Third Kind\n\nClose En...
# 47841    29919  João Ricardo (músico)\n\nJoão Ricardo (Arcozel...
# 47842  3872745  I Got a Boy (canção)\n\n"I Got a Boy" é uma ca...
# 47843  5829079  Buy n Large\n\nA Buy n Large Corporation, abre...
# 47844  2263728  Push (filme)\n\nPush () é um filme realizado e...
# 47845  4506663  Rio Preto de Luto\n\n"Rio Preto de Luto" é uma...
# 47846  2013835  Emotion (canção de Samantha Sang)\n\n"Emotion"...
# 47847   955865  Jade Barbosa\n\nJade Fernandes Barbosa (Rio de...
# 47848  1461607  Ulver\n\nUlver (lobos, em norueguês) é uma ban...
# 47849  1702026  Bento Vôlei\n\nA Sociedade Educativa, Cultural...
# 47850  4571779  Síndrome de Diógenes\n\nA síndrome de Diógenes...
# 47851  1739279  Protetorado de Áden\n\nO Protetorado de Áden (...
# 47852  2532233  Waldo Motta\n\nWaldo Motta (ou Valdo Motta, no...
#
#                                                    title  \
# 0                              Lista de vilões de Ben 10
# 1                        História da televisão no Brasil
# 2                                             Magnetismo
# 3                                             Wally West
# 4                                      Guerra Irã-Iraque
# 5                                                  Quito
# 6                                     Aquecimento global
# 7                               Cronologia da Rede Globo
# 8                                           Idade Antiga
# 9                                 Cronologia da RecordTV
# 10                                        Estereoquímica
# 11           História do Sistema Brasileiro de Televisão
# 12     História operacional da Luftwaffe na Segunda G...
# 13                                  Governo Michel Temer
# 14                                  Anarquismo no Brasil
# 15                Lista de personagens de Inazuma Eleven
# 16                                                Cabala
# 17                        Imigração portuguesa no Brasil
# 18                          Imigração italiana no Brasil
# 19                      História em quadrinhos no Brasil
# 20                                     História do Japão
# 21                                        Gueorgui Júkov
# 22        História das relações internacionais do Brasil
# 23                                   Guerra das Malvinas
# 24                               Acadêmicos do Salgueiro
# 25                                              Piratini
# 26                                            Anarquismo
# 27                        Lista de alienígenas de Ben 10
# 28                                       Anthony Bottoms
# 29                                      John Keith Irwin
# ...                                                  ...
# 47823                                             Asmara
# 47824                        Bate Folha (Rio de Janeiro)
# 47825           Parque Nacional da Chapada dos Veadeiros
# 47826                                        Feminicídio
# 47827                                 Fernanda Venturini
# 47828                     Voo SA de Transport Aérien 730
# 47829                                     AU Microscopii
# 47830                           Nossa Senhora Achiropita
# 47831                                Ludgero Pinto Basto
# 47832                     Instituto de Economia Agrícola
# 47833                                Francesco Matarazzo
# 47834                                         Pepe Reina
# 47835                   Companhia de Teatro Zaira Médice
# 47836                             Café (estabelecimento)
# 47837                             Caso do Rio de Janeiro
# 47838                                        Blockstream
# 47839                                       Codex Aleppo
# 47840                 Close Encounters of the Third Kind
# 47841                              João Ricardo (músico)
# 47842                               I Got a Boy (canção)
# 47843                                        Buy n Large
# 47844                                       Push (filme)
# 47845                                  Rio Preto de Luto
# 47846                  Emotion (canção de Samantha Sang)
# 47847                                       Jade Barbosa
# 47848                                              Ulver
# 47849                                        Bento Vôlei
# 47850                               Síndrome de Diógenes
# 47851                                Protetorado de Áden
# 47852                                        Waldo Motta
#
#                                                url
# 0      https://pt.wikipedia.org/wiki?curid=1018503
# 1      https://pt.wikipedia.org/wiki?curid=2737450
# 2        https://pt.wikipedia.org/wiki?curid=31862
# 3       https://pt.wikipedia.org/wiki?curid=198795
# 4       https://pt.wikipedia.org/wiki?curid=182603
# 5        https://pt.wikipedia.org/wiki?curid=27121
# 6          https://pt.wikipedia.org/wiki?curid=232
# 7      https://pt.wikipedia.org/wiki?curid=3143570
# 8      https://pt.wikipedia.org/wiki?curid=4286052
# 9      https://pt.wikipedia.org/wiki?curid=2324636
# 10     https://pt.wikipedia.org/wiki?curid=1475770
# 11     https://pt.wikipedia.org/wiki?curid=3164793
# 12     https://pt.wikipedia.org/wiki?curid=5346732
# 13     https://pt.wikipedia.org/wiki?curid=5084779
# 14     https://pt.wikipedia.org/wiki?curid=4427907
# 15     https://pt.wikipedia.org/wiki?curid=2946203
# 16        https://pt.wikipedia.org/wiki?curid=9105
# 17       https://pt.wikipedia.org/wiki?curid=97372
# 18       https://pt.wikipedia.org/wiki?curid=97388
# 19      https://pt.wikipedia.org/wiki?curid=127871
# 20         https://pt.wikipedia.org/wiki?curid=989
# 21      https://pt.wikipedia.org/wiki?curid=132239
# 22     https://pt.wikipedia.org/wiki?curid=1321355
# 23        https://pt.wikipedia.org/wiki?curid=5096
# 24      https://pt.wikipedia.org/wiki?curid=103169
# 25       https://pt.wikipedia.org/wiki?curid=34153
# 26         https://pt.wikipedia.org/wiki?curid=230
# 27     https://pt.wikipedia.org/wiki?curid=1562777
# 28     https://pt.wikipedia.org/wiki?curid=4528100
# 29     https://pt.wikipedia.org/wiki?curid=2564674
# ...                                            ...
# 47823    https://pt.wikipedia.org/wiki?curid=36747
# 47824  https://pt.wikipedia.org/wiki?curid=2184761
# 47825   https://pt.wikipedia.org/wiki?curid=267762
# 47826  https://pt.wikipedia.org/wiki?curid=4120876
# 47827   https://pt.wikipedia.org/wiki?curid=157805
# 47828  https://pt.wikipedia.org/wiki?curid=4247608
# 47829  https://pt.wikipedia.org/wiki?curid=5660911
# 47830  https://pt.wikipedia.org/wiki?curid=4965390
# 47831  https://pt.wikipedia.org/wiki?curid=5158557
# 47832  https://pt.wikipedia.org/wiki?curid=2037181
# 47833    https://pt.wikipedia.org/wiki?curid=74380
# 47834   https://pt.wikipedia.org/wiki?curid=406696
# 47835  https://pt.wikipedia.org/wiki?curid=4763784
# 47836  https://pt.wikipedia.org/wiki?curid=1114270
# 47837  https://pt.wikipedia.org/wiki?curid=5483057
# 47838  https://pt.wikipedia.org/wiki?curid=5132804
# 47839  https://pt.wikipedia.org/wiki?curid=1103465
# 47840   https://pt.wikipedia.org/wiki?curid=268851
# 47841    https://pt.wikipedia.org/wiki?curid=29919
# 47842  https://pt.wikipedia.org/wiki?curid=3872745
# 47843  https://pt.wikipedia.org/wiki?curid=5829079
# 47844  https://pt.wikipedia.org/wiki?curid=2263728
# 47845  https://pt.wikipedia.org/wiki?curid=4506663
# 47846  https://pt.wikipedia.org/wiki?curid=2013835
# 47847   https://pt.wikipedia.org/wiki?curid=955865
# 47848  https://pt.wikipedia.org/wiki?curid=1461607
# 47849  https://pt.wikipedia.org/wiki?curid=1702026
# 47850  https://pt.wikipedia.org/wiki?curid=4571779
# 47851  https://pt.wikipedia.org/wiki?curid=1739279
# 47852  https://pt.wikipedia.org/wiki?curid=2532233
#
# [47853 rows x 4 columns]

# %%
###  pick only the first 1/21 of the corpus containing the lenghtier "text"
LANG_TEXT = LANG_TEXT[0:LANG_TEXT.shape[0]//21]

# %%
LANG_TEXT.to_csv(f"{LM_PATH}/Wiki_PT_Corpus.csv", index=False)

# %%
#LANG_TEXT = pd.read_csv(f"{LM_PATH}/Wiki_PT_Corpus.csv")
LANG_TEXT = pd.read_csv(path/'Wiki_PT_Corpus.csv')

# %%
(LANG_TEXT.assign(labels = 0)
    .pipe(lambda x: x[['labels', 'text']])
    .to_csv(path/'Wiki_PT_Corpus2.csv', header=None, index=False))

# %%
# Getting rid of the title name in the text field
def split_title_from_text(text):
    words = text.split("\n\n")
    if len(words) >= 2:
        return ''.join(words[1:])
    else:
        return ''.join(words)
    
LANG_TEXT['text'] = LANG_TEXT['text'].apply(lambda x: split_title_from_text(x))

# %%
LANG_TEXT['text'].apply(lambda x: len(x.split(" "))).sum()
# Out:
# 104717838

# %%
len(set(''.join(LANG_TEXT['text'].values).split(" ")))
# Out:
# 4001022

# %%
re1 = re.compile(r'  +')

def fixup(x):
    x = x.replace('#39;', "'").replace('amp;', '&').replace('#146;', "'").replace(
        'nbsp;', ' ').replace('#36;', '$').replace('\\n', "\n").replace('quot;', "'").replace(
        '<br />', "\n").replace('\\"', '"').replace('<unk>','u_n').replace(' @.@ ','.').replace(
        ' @-@ ','-').replace('\\', ' \\ ')
    return re1.sub(' ', html.unescape(x))

# %%
def get_texts(df, n_lbls=1):
    labels = df.iloc[:,range(n_lbls)].values.astype(np.int64)
    texts = f'\n{BOS} {FLD} 1 ' + df[n_lbls].astype(str)
    for i in range(n_lbls+1, len(df.columns)): texts += f' {FLD} {i-n_lbls} ' + df[i].astype(str)
    #texts = texts.apply(fixup).values.astype(str)
    #teste
    texts = texts.apply(fixup).values.astype(str)
    tok = Tokenizer().process_all(partition_by_cores(texts,n_cpus=1))  #, lang='pt'
    #fim teste

    #tok = Tokenizer().proc_all_mp(partition_by_cores(texts)) # splits the list into sublists for processing by each core
    # Lower and upper case is inside the tokenizer
    return tok, list(labels)

def get_all(df, n_lbls):
    tok, labels = [], []
    for i, r in enumerate(df):
        print(i)
        tok_, labels_ = get_texts(r, n_lbls)
        tok += tok_;
        labels += labels_
    return tok, labels

# %%
LANG_TEXT = pd.read_csv(path/"Wiki_PT_Corpus2.csv", header=None)#, chunksize=5000)

# %%
trn_texts,val_texts = train_test_split(
    LANG_TEXT, test_size=0.1) # split the data into train and validation sets

# %%
np.random.seed(42)
trn_idx = np.random.permutation(len(trn_texts)) # generate a random ordering
val_idx = np.random.permutation(len(val_texts))

df_trn = trn_texts.iloc[trn_idx,:] # sort things randomly
df_val = val_texts.iloc[val_idx,:] # sort things randomly

df_trn.columns = ['labels', 'text']
df_val.columns = ['labels', 'text']

df_trn.to_csv(path/'train.csv', header=False, index=False)
df_val.to_csv(path/'test.csv', header=False, index=False) # saving the data in our new format to disk

# %%
#chunksize = 10000
chunksize = 5000
df_trn = pd.read_csv(path/'train.csv', header=None, chunksize=chunksize)
df_val = pd.read_csv(path/'test.csv', header=None, chunksize=chunksize)

# %%
tok_trn, trn_labels = get_all(df_trn, 1)
tok_val, val_labels = get_all(df_val, 1)
# Out:
# 0
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 393, in _send_bytes
#     header = struct.pack("!i", n)
# struct.error: 'i' format requires -2147483648 <= number <= 2147483647

# %%
# create a tmp directory to store the upcoming numpy arrays
(path/'tmp').mkdir(exist_ok=True)

# save the train and validation tokens in the tmp directories
np.save(LM_PATH/'tmp'/'tok_trn.npy', tok_trn)
np.save(LM_PATH/'tmp'/'tok_val.npy', tok_val)

# %% [markdown]
# ## Loading dataset

# %%
tok_trn = np.load(LM_PATH/'tmp'/'tok_trn.npy')
tok_val = np.load(LM_PATH/'tmp'/'tok_val.npy')

# %%
# Identify the most common tokens and numericalizing the text
freq = Counter(p for o in tok_trn for p in o) 
freq.most_common(25)
# Out:
# [(',', 6680801),
#  ('de', 5008496),
#  ('.', 3989783),
#  ('a', 3586998),
#  ('o', 2909074),
#  ('e', 2673391),
#  ('"', 2242948),
#  ('em', 1692491),
#  ('que', 1583403),
#  ('do', 1567176),
#  ('da', 1426734),
#  ('\n\n', 1156155),
#  ('-', 1024169),
#  ('um', 916574),
#  ('para', 909453),
#  ('com', 900413),
#  ('os', 870284),
#  ('no', 845049),
#  ('uma', 815469),
#  ('se', 731377),
#  ('na', 707320),
#  (')', 667212),
#  ('(', 654354),
#  ('por', 624549),
#  ('é', 596973)]

# %%
em_sz,nh,nl = 400,1150,3
wd=1e-7
bptt=70
opt_fn = partial(optim.Adam, betas=(0.8, 0.99))

# %% [markdown]
# ### Maximum vocabulary size (60000 tokens), batch size = 32, dropout factor = 0.7, learning rate = 1e-3/2

# %%
# Truncating our vocab to ignore the rare words
max_vocab = 60000
min_freq = 5

itos = [o for o,c in freq.most_common(max_vocab) if c>min_freq] # getting rid of the rare words
itos.insert(0, '_pad_') # 
itos.insert(0, '_unk_') # itos is the list of all the strings in the vocab

# %%
# creating a index-key dictionary for our vocabulary
stoi = collections.defaultdict(lambda:0, {v:k for k,v in enumerate(itos)})
len(itos)

# %%
# creating a index representation for our train and validation dataset
trn_lm = np.array([[stoi[o] for o in p] for p in tok_trn])
val_lm = np.array([[stoi[o] for o in p] for p in tok_val])

# %%
# saving our indexed representation of our dataset to disk
# we also save the index-word mapping to retrieve the complete text representation from these numpy arrays
np.save(LM_PATH/'tmp'/'trn_ids.npy', trn_lm)
np.save(LM_PATH/'tmp'/'val_ids.npy', val_lm)
pickle.dump(itos, open(LM_PATH/'tmp'/'itos.pkl', 'wb'))

# %%
# Loading the indexed representation of our dataset from disk
# we also load the index-word mapping to to help us convert the indexes to word datasets, if need be.
trn_lm = np.load(LM_PATH/'tmp'/'trn_ids.npy')
val_lm = np.load(LM_PATH/'tmp'/'val_ids.npy')
itos = pickle.load(open(LM_PATH/'tmp'/'itos.pkl', 'rb'))

# %%
# checking vocabulary size
vs=len(itos)
vs,len(trn_lm)

# %%
bs = 32

# %%
trn_dl = LanguageModelLoader(np.concatenate(trn_lm), bs, bptt)
val_dl = LanguageModelLoader(np.concatenate(val_lm), bs, bptt)
md = LanguageModelData(PATH, 1, vs, trn_dl, val_dl, bs=bs, bptt=bptt)

# %%
drops = np.array([0.25, 0.1, 0.2, 0.02, 0.15])*0.7

# %%
learner= md.get_model(opt_fn, em_sz, nh, nl, 
    dropouti=drops[0], dropout=drops[1], wdrop=drops[2], dropoute=drops[3], dropouth=drops[4])

# %%
learner.metrics = [accuracy]
learner.unfreeze()

# %%
lr=1e-3
lrs = lr

# %%
learner.fit(lrs/2, 1, wds=wd, use_clr=(32,2), cycle_len=1)

# %%
learner.sched.plot_loss()

# %%
learner.save('lm_PT_v2_fastai')

# %%
# Learning rate checking
learner.lr_find(start_lr=lrs/10, end_lr=lrs*10, linear=True)

# %%
learner.sched.plot()

# %% [markdown]
# ### Dropout factor = 0.05, learning rate = 1e-3

# %%
drops = np.array([0.25, 0.1, 0.2, 0.02, 0.15])*0.05

# %%
learner= md.get_model(opt_fn, em_sz, nh, nl, 
    dropouti=drops[0], dropout=drops[1], wdrop=drops[2], dropoute=drops[3], dropouth=drops[4])

# %%
learner.metrics = [accuracy]
learner.unfreeze()

# %%
lr=1e-3
lrs = lr

# %%
learner.fit(lrs, 1, wds=wd, use_clr=(32,2), cycle_len=1)

# %%
learner.sched.plot_loss()

# %%
learner.save('lm_PT_v2_fastai_dp_005')

# %%
# Learning rate checking
learner.lr_find(start_lr=lrs/10, end_lr=lrs*10, linear=True)

# %%
learner.sched.plot()

# %% [markdown]
# ### Reduced vocabulary size (30000 tokens), batch size = 52

# %%
# Truncating our vocab to ignore the rare words
max_vocab = 30000
min_freq = 5

itos = [o for o,c in freq.most_common(max_vocab) if c>min_freq] # getting rid of the rare words
itos.insert(0, '_pad_') # 
itos.insert(0, '_unk_') # itos is the list of all the strings in the vocab

# %%
# creating a index-key dictionary for our vocabulary
stoi = collections.defaultdict(lambda:0, {v:k for k,v in enumerate(itos)})
len(itos)

# %%
# creating a index representation for our train and validation dataset
trn_lm = np.array([[stoi[o] for o in p] for p in tok_trn])
val_lm = np.array([[stoi[o] for o in p] for p in tok_val])

# %%
# saving our indexed representation of our dataset to disk
# we also save the index-word mapping to retrieve the complete text representation from these numpy arrays
np.save(LM_PATH/'tmp'/'trn_ids.npy', trn_lm)
np.save(LM_PATH/'tmp'/'val_ids.npy', val_lm)
pickle.dump(itos, open(LM_PATH/'tmp'/'itos.pkl', 'wb'))

# %%
# Loading the indexed representation of our dataset from disk
# we also load the index-word mapping to to help us convert the indexes to word datasets, if need be.
trn_lm = np.load(LM_PATH/'tmp'/'trn_ids.npy')
val_lm = np.load(LM_PATH/'tmp'/'val_ids.npy')
itos = pickle.load(open(LM_PATH/'tmp'/'itos.pkl', 'rb'))

# %%
# checking vocabulary size
vs=len(itos)
vs,len(trn_lm)

# %%
bs = 52

# %%
trn_dl = LanguageModelLoader(np.concatenate(trn_lm), bs, bptt)
val_dl = LanguageModelLoader(np.concatenate(val_lm), bs, bptt)
md = LanguageModelData(PATH, 1, vs, trn_dl, val_dl, bs=bs, bptt=bptt)

# %%
drops = np.array([0.25, 0.1, 0.2, 0.02, 0.15])*0.05

# %%
learner= md.get_model(opt_fn, em_sz, nh, nl, 
    dropouti=drops[0], dropout=drops[1], wdrop=drops[2], dropoute=drops[3], dropouth=drops[4])

# %%
# Learning rate checking
learner.lr_find(start_lr=lrs/10, end_lr=lrs*10, linear=True)

# %%
learner.sched.plot()

# %%
learner.fit(lrs, 1, wds=wd, use_clr=(32,2), cycle_len=1)

# %%
learner.sched.plot_loss()

# %%
learner.save('lm_PT_v2_fastai_dp_005_30k_tokens_bs52')

# %% [markdown]
# ### 1-cycle

# %%
# Truncating our vocab to ignore the rare words
max_vocab = 30000
min_freq = 5

itos = [o for o,c in freq.most_common(max_vocab) if c>min_freq] # getting rid of the rare words
itos.insert(0, '_pad_') # 
itos.insert(0, '_unk_') # itos is the list of all the strings in the vocab

# %%
# creating a index-key dictionary for our vocabulary
stoi = collections.defaultdict(lambda:0, {v:k for k,v in enumerate(itos)})
len(itos)
# Out:
# 30002

# %%
# creating a index representation for our train and validation dataset
trn_lm = np.array([[stoi[o] for o in p] for p in tok_trn])
val_lm = np.array([[stoi[o] for o in p] for p in tok_val])

# %%
# saving our indexed representation of our dataset to disk
# we also save the index-word mapping to retrieve the complete text representation from these numpy arrays
np.save(LM_PATH/'tmp'/'trn_ids.npy', trn_lm)
np.save(LM_PATH/'tmp'/'val_ids.npy', val_lm)
pickle.dump(itos, open(LM_PATH/'tmp'/'itos.pkl', 'wb'))

# %%
# Loading the indexed representation of our dataset from disk
# we also load the index-word mapping to to help us convert the indexes to word datasets, if need be.
trn_lm = np.load(LM_PATH/'tmp'/'trn_ids.npy')
val_lm = np.load(LM_PATH/'tmp'/'val_ids.npy')
itos = pickle.load(open(LM_PATH/'tmp'/'itos.pkl', 'rb'))

# %%
# checking vocabulary size
vs=len(itos)
vs,len(trn_lm)
# Out:
# (30002, 42750)

# %%
bs = 52

# %%
trn_dl = LanguageModelLoader(np.concatenate(trn_lm), bs, bptt)
val_dl = LanguageModelLoader(np.concatenate(val_lm), bs, bptt)
md = LanguageModelData(PATH, 1, vs, trn_dl, val_dl, bs=bs, bptt=bptt)

# %%
opt_fn = partial(optim.SGD, momentum=0.9)

# %% [markdown]
# #### Dropout constant = 0.05, no gradient clipping

# %%
drops = np.array([0.25, 0.1, 0.2, 0.02, 0.15])*0.05 #the higher the lr, the lower dp

# %%
learner= md.get_model(opt_fn, em_sz, nh, nl, 
    dropouti=drops[0], dropout=drops[1], wdrop=drops[2], dropoute=drops[3], dropouth=drops[4])

# %%
learner.metrics = [accuracy]
learner.unfreeze()

# %%
learner.lr_find2(num_it=200)

# %%
learner.sched.plot()

# %%
lr = 5

# %%
learner.fit(lr, 1, cycle_len=2, use_clr_beta=(10,10,0.95,0.85))

# %%
learner.sched.plot_loss()

# %%
learner.save('lm_PT_1_cycle')

# %% [markdown]
# #### Dropout constant = 0.1, gradient clipping = 0.25

# %%
drops = np.array([0.25, 0.1, 0.2, 0.02, 0.15])*0.1

# %%
learner= md.get_model(opt_fn, em_sz, nh, nl, 
    dropouti=drops[0], dropout=drops[1], wdrop=drops[2], dropoute=drops[3], dropouth=drops[4])

# %%
learner.metrics = [accuracy]
learner.clip=0.25
learner.unfreeze()

# %%
learner.clip
# Out:
# 0.25

# %%
learner.lr_find2(num_it=500)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
#   2%|▏         | 500/30505 [02:53<2:53:10,  2.89it/s, loss=7.19]

# %%
learner.sched.plot()

# %%
lr = 6

# %%
learner.fit(lr, 1, cycle_len=2, use_clr_beta=(10,10,0.95,0.85))
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=2), HTML(value='')))
# epoch      trn_loss   val_loss   accuracy
#     0      3.808152   3.901497   0.273225
#     1      3.604043   3.611512   0.306141
# [array([ 3.61151]), 0.30614125034985701]

# %%
learner.sched.plot_loss()

# %%
learner.save('lm_PT_1_cycle_dp_gc')

# %% [markdown]
# ## Language Model Test

# %%
learner.load('lm_PT_1_cycle_10_epochs_from_scratch')

# %%
m = learner.model
m.eval()
m[0].bs = 1

# %%
sen = "o universo é"

# %%
idxs = np.array([[stoi[p] for p in sen.strip().split(" ")]])
idxs
# Out:
# array([[   6, 1221,   26]])

# %%
def get_next(inp):
    m[0].bs =1
    idxs = np.array([[stoi[p] for p in inp.strip().split(" ")]])
    probs = m(VV(idxs))
    encc = probs[-1][-1][-1][-1].squeeze()
    p = learner.model[1].decoder(encc).exp()
    ret = to_np(torch.multinomial(p, 1)[0])
        
    while ret == 0:
        ret = to_np(torch.multinomial(learner.model[1].decoder(encc).exp(), 1)[0])
    
    try:
        r = itos[ret[0]]
    except:
        r = "oor"
    return r


def get_next_n(inp, n):
    res = inp
    for i in range(n):
        c = get_next(inp)
        res = res + " " + c
        inp = inp.strip().split(" ") + [c]    
        inp = ' '.join(inp)
        
    return res

# %%
def get_next2(inp):
    m[0].bs =1
    idxs = np.array([[stoi[p] for p in inp.strip().split(" ")]])
    probs = m(VV(idxs))
    encc = probs[-1][-1][-1][-1].squeeze()
    pred = to_np(learner.model[1].decoder(encc).exp()).argmax()
        
    if pred == 0:
        pred = to_np(learner.model[1].decoder(encc).exp()).argsort()[-2]
    
    try:
        r = itos[pred]
    except:
        r = "oor"
    return r


def get_next_n2(inp, n):
    res = inp
    for i in range(n):
        c = get_next2(inp)
        res = res + " " + c
        inp = inp.strip().split(" ") + [c]    
        inp = ' '.join(inp)
        
    return res

# %%
print(get_next(sen))
# Out:
# visto

# %%
print(get_next_n(sen, 70))
# Out:
# o universo é comparável a estrutura interna da cidade turística de identificação único pesquisador , fazendo diferentes contextos que já tinha muito insatisfeito na ocasião , lançado na quarta representante estadunidense , num esforço técnico em contaminação por meio ambiente . a praça da cadeia distribuído para manter o jogo se ou seja uma trégua e tudo o dentista f.c .
#
#  uma banda 2004 desenvolvia , e então anular sua refinaria de

# %%
print(get_next_n("o brasil", 70))
# Out:
# o brasil para " machado de seus jornalistas e ambiente animar numa ocasião em dezesseis anos 80 coríntios que , ela da electric light drop em 1961 pode sobreviver em x e chilena para imitar ações críticas a reside tecnologicamente superior vi é castelhano chamado mercado internacional william levy 95 páginas intitulado tradicionais definem sua elevada presença e há muito parecido com foco de " marrom similar a federação internacional com gemas

# %%
print(get_next_n("a vida", 70))
# Out:
# a vida ligada à direita controlado pelas péssimas colheitas vendidas como resultado decisivo , do norte esperava o cultivo da linhagem preta nos tempos de médicos e a duração publica " wall street language , e historiadores não tomou a criação , enfim , não se ouvidas e todos esses cientistas , primeiro jogo inaugural do primeiro presidente legítimo , tendo que tem uma paixão das ideias e dificuldade do teatro onde

# %%
print(get_next_n("o tribunal de contas", 70))
# Out:
# o tribunal de contas foram dadas as representações de início do ouro ou outra percentagem para esclarecer que cria pórtico 9 1717 . por razões para um opcional na frente ocidental e por meio - no norte - menos garantido , talvez em uma máquina branca havia encontrado à paz selêucida , um exemplo artist city para colocar o dj e prior de plata .
#
#
#
#  no total .
#
#  ele faz

# %%
print(get_next_n2("o universo é", 2))
# Out:
# o universo é um grupo

# %%
print(get_next_n2("o brasil", 2))
# Out:
# o brasil .

# %%
print(get_next_n2("a vida", 2))
# Out:
# a vida noturna ,

# %%
print(get_next_n2("o tribunal de contas", 2))
# Out:
# o tribunal de contas de acordo

# %%
learner.summary
# Out:
# <bound method Learner.summary of SequentialRNN(
#   (0): RNN_Encoder(
#     (encoder): Embedding(30002, 400, padding_idx=1)
#     (encoder_with_dropout): EmbeddingDropout(
#       (embed): Embedding(30002, 400, padding_idx=1)
#     )
#     (rnns): ModuleList(
#       (0): WeightDrop(
#         (module): LSTM(400, 1150)
#       )
#       (1): WeightDrop(
#         (module): LSTM(1150, 1150)
#       )
#       (2): WeightDrop(
#         (module): LSTM(1150, 400)
#       )
#     )
#     (dropouti): LockedDropout(
#     )
#     (dropouths): ModuleList(
#       (0): LockedDropout(
#       )
#       (1): LockedDropout(
#       )
#       (2): LockedDropout(
#       )
#     )
#   )
#   (1): LinearDecoder(
#     (decoder): Linear(in_features=400, out_features=30002)
#     (dropout): LockedDropout(
#     )
#   )
# )>
